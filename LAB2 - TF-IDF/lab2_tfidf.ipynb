# %%
# !pip install simplemma

# %%
from simplemma import text_lemmatizer
import pandas as pd
import numpy as np
import ast
import re

# %% [markdown]
# Veri seti ön işleme

# %%
# stop word ayıklaması yapmayan metin temizleme fonk.
def clean_text(text):
    text = text.replace("Â", "a")
    text = text.replace("â", "a")
    text = text.replace("î", "i")
    text = text.replace("Î", "ı")
    text = text.replace("İ", "i")
    text = text.replace("I", "ı")
    text = text.replace(u"\u00A0", " ")
    text = text.replace("|", " ")

    text = re.sub(r"@[A-Za-z0-9]+", " ", text)
    text = re.sub(r"(.)\1+", r"\1\1", text)
    text = re.sub(r"https?:\/\/\S+", " ", text)
    text = re.sub(r"http?:\/\/\S+", " ", text)
    text = re.sub(r"\n", " ", text)
    text = re.sub(r"#(\w+)", " ", text)
    text = re.sub(r"^\x00-\x7F]+", " ", text)
    text = re.sub(r"[^A-Za-zâîığüşöçİĞÜŞÖÇ]+", " ", text)
    text = re.sub(r"((https://[^\s]+))", " ", text)
    text = " ".join(text.lower().strip().split())

    return " ".join(text_lemmatizer(text, lang="tr"))

# %%
clean_text("Hey! Naber???İyilik, senden... Ben de iyiyim.Çocuk filmi Kirpi Sonic filminin devam halkası olan yapımda, insan biçiminde bir kirpi olan Sonic'in atıldığı maceralar konu ediliyor.")
# Out:
# 'hey naber iyi sen ben de iyi çocuk film kirpi sonic film devam halka ol yapım insan biçim bir kirpi ol sonic in at macera konu et'

# %%
df = pd.read_excel("filmveriseti.xlsx")
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk

# %%
df["tur_list"] = df["tur"].apply(ast.literal_eval)
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                        tur_list
# 0            [Dram, Biyografik]
# 1     [Animasyon, Aile, Macera]
# 2           [Fantastik, Macera]
# 3                      [Komedi]
# 4  [Aksiyon, Fantastik, Macera]

# %%
def clean_row(row):
    ozet = clean_text(row["ozet ve detaylar"])
    tur = clean_text(" ".join(row["tur_list"]))
    return ozet + " " + tur

# %%
clean_row(df.iloc[1])
# Out:
# 'çocuk film kirpi sonic film devam halka ol yapım insan biçim bir kirpi ol sonic in at macera konu et green hills e yerleş sonic in tek istek gerçek bir kahraman ol için gerek özellik sahip ol kanıtlayabil sonic in sınav dr robotnik in ortak knuckes ile birlikte medeniyet yok et güç sahip bir zümrüt ara için geri dön baş zümrüt yanlış el geç engelle için sonic yardımcı tails ile birlikte macera dolu bir yolculuk çıkar animasyon aile macera'

# %%
df["clean"] = df.apply(lambda row: clean_row(row), axis=1)
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                        tur_list  \
# 0            [Dram, Biyografik]
# 1     [Animasyon, Aile, Macera]
# 2           [Fantastik, Macera]
# 3                      [Komedi]
# 4  [Aksiyon, Fantastik, Macera]
#
#                                                clean
# 0  arabesk unut kadın ses biri ol berge in hayat ...
# 1  çocuk film kirpi sonic film devam halka ol yap...
# 2  karanlık büyücü gellert grindelwald büyücülük ...
# 3  aykut enişte sev kadın evlilik arife kendi tür...
# 4  morbius hastalık deva bul çalış bambaşka bir v...

# %%
filmler = df["clean"].values
print(filmler[:3])
# Out:
# ['arabesk unut kadın ses biri ol berge in hayat anlat film berge ol bil belgin in ankara dan adana ya ora da yaşa aşk ardından ebediyet uza öykü anlat yıl mersin de yedi çocuk bir aile en küçük çocuk ol dünya gelir belgin anne ve baba boşa hayat kökten bir biçim değiş ankara da yaşa anne başka kimse yok baba yoksun iç derin bir boşluk aç öte yan konservatuara gir başarı katmer gelecek umut ilk aşk abdullah tan ayır yara al ama o en büyük güç yetenek ankara nın prestij mekan feyman kulüp te keşfet birlikte parla genç bir yıldız berge e dönüş ancak zaman koşul yap kontrat sebep berge bir süre çalış için anne birlikte adana ya gider adana da çalış müzikhol sahne ve müzik tarz değiş zor kal daha sonra evlen halis serbest ile karşılaşma manipülatif olay dizi iç bul kendi halis serbest le yap evlilik i düşle tersine berge i hayat kopar şiddet dolu gün tüm yalnız kariyer en güzel yer halis serbest in kezzap saldırı uğra berge bir göz kaybet berge yaşa trajedi rağmen sahne dön olağanüstü şarkıcılık türkiye çap şöhret bir şarkı ol halis in tehdit taciz ve şiddet seyret gerilim ilişki git gellerle devam et berge hep korku iç yaşar sonunda kesin bir biçim halis serbest ten kurtul düşün bir yolculuk silah saldırı uğra anne ağır yarala bu saldırı berge hayat kaybet henüz yaş berge öl i hem bir kurban hem de arabesk kraliçe ol insan kalp kazın dram biyografik'
#  'çocuk film kirpi sonic film devam halka ol yapım insan biçim bir kirpi ol sonic in at macera konu et green hills e yerleş sonic in tek istek gerçek bir kahraman ol için gerek özellik sahip ol kanıtlayabil sonic in sınav dr robotnik in ortak knuckes ile birlikte medeniyet yok et güç sahip bir zümrüt ara için geri dön baş zümrüt yanlış el geç engelle için sonic yardımcı tails ile birlikte macera dolu bir yolculuk çıkar animasyon aile macera'
#  'karanlık büyücü gellert grindelwald büyücülük dünya kontrol el geçir için hareket geç bu öğren profesör albus dumbledore önce o tek baş dur çalış ancak bu başar dumbledore ara büyücü cadı ve cesur bir muggle fırıncı oluş ekip yönetim büyüzoolog newt scamander a emanet et tehlike bir görev üstlen ekip bir yan canavar mücadele et bir yan da gün geç sayı art grindelwald un mürit savaş git art risk karşı dumbledore daha ne kadar kenar bekleyebil fantastik macera']

# %% [markdown]
# Sözlük (Vocab) oluşturma

# %%
word2idx = {}
i = 0

for film in filmler:
    for sozcuk in film.split():
        if sozcuk not in word2idx:
            word2idx[sozcuk] = i
            i += 1

# %%
word2idx
# Out:
# {'arabesk': 0,
#  'unut': 1,
#  'kadın': 2,
#  'ses': 3,
#  'biri': 4,
#  'ol': 5,
#  'berge': 6,
#  'in': 7,
#  'hayat': 8,
#  'anlat': 9,
#  'film': 10,
#  'bil': 11,
#  'belgin': 12,
#  'ankara': 13,
#  'dan': 14,
#  'adana': 15,
#  'ya': 16,
#  'ora': 17,
#  'da': 18,
#  'yaşa': 19,
#  'aşk': 20,
#  'ardından': 21,
#  'ebediyet': 22,
#  'uza': 23,
#  'öykü': 24,
#  'yıl': 25,
#  'mersin': 26,
#  'de': 27,
#  'yedi': 28,
#  'çocuk': 29,
#  'bir': 30,
#  'aile': 31,
#  'en': 32,
#  'küçük': 33,
#  'dünya': 34,
#  'gelir': 35,
#  'anne': 36,
#  've': 37,
#  'baba': 38,
#  'boşa': 39,
#  'kökten': 40,
#  'biçim': 41,
#  'değiş': 42,
#  'başka': 43,
#  'kimse': 44,
#  'yok': 45,
#  'yoksun': 46,
#  'iç': 47,
#  'derin': 48,
#  'boşluk': 49,
#  'aç': 50,
#  'öte': 51,
#  'yan': 52,
#  'konservatuara': 53,
#  'gir': 54,
#  'başarı': 55,
#  'katmer': 56,
#  'gelecek': 57,
#  'umut': 58,
#  'ilk': 59,
#  'abdullah': 60,
#  'tan': 61,
#  'ayır': 62,
#  'yara': 63,
#  'al': 64,
#  'ama': 65,
#  'o': 66,
#  'büyük': 67,
#  'güç': 68,
#  'yetenek': 69,
#  'nın': 70,
#  'prestij': 71,
#  'mekan': 72,
#  'feyman': 73,
#  'kulüp': 74,
#  'te': 75,
#  'keşfet': 76,
#  'birlikte': 77,
#  'parla': 78,
#  'genç': 79,
#  'yıldız': 80,
#  'e': 81,
#  'dönüş': 82,
#  'ancak': 83,
#  'zaman': 84,
#  'koşul': 85,
#  'yap': 86,
#  'kontrat': 87,
#  'sebep': 88,
#  'süre': 89,
#  'çalış': 90,
#  'için': 91,
#  'gider': 92,
#  'müzikhol': 93,
#  'sahne': 94,
#  'müzik': 95,
#  'tarz': 96,
#  'zor': 97,
#  'kal': 98,
#  'daha': 99,
#  'sonra': 100,
#  'evlen': 101,
#  'halis': 102,
#  'serbest': 103,
#  'ile': 104,
#  'karşılaşma': 105,
#  'manipülatif': 106,
#  'olay': 107,
#  'dizi': 108,
#  'bul': 109,
#  'kendi': 110,
#  'le': 111,
#  'evlilik': 112,
#  'i': 113,
#  'düşle': 114,
#  'tersine': 115,
#  'kopar': 116,
#  'şiddet': 117,
#  'dolu': 118,
#  'gün': 119,
#  'tüm': 120,
#  'yalnız': 121,
#  'kariyer': 122,
#  'güzel': 123,
#  'yer': 124,
#  'kezzap': 125,
#  'saldırı': 126,
#  'uğra': 127,
#  'göz': 128,
#  'kaybet': 129,
#  'trajedi': 130,
#  'rağmen': 131,
#  'dön': 132,
#  'olağanüstü': 133,
#  'şarkıcılık': 134,
#  'türkiye': 135,
#  'çap': 136,
#  'şöhret': 137,
#  'şarkı': 138,
#  'tehdit': 139,
#  'taciz': 140,
#  'seyret': 141,
#  'gerilim': 142,
#  'ilişki': 143,
#  'git': 144,
#  'gellerle': 145,
#  'devam': 146,
#  'et': 147,
#  'hep': 148,
#  'korku': 149,
#  'yaşar': 150,
#  'sonunda': 151,
#  'kesin': 152,
#  'ten': 153,
#  'kurtul': 154,
#  'düşün': 155,
#  'yolculuk': 156,
#  'silah': 157,
#  'ağır': 158,
#  'yarala': 159,
#  'bu': 160,
#  'henüz': 161,
#  'yaş': 162,
#  'öl': 163,
#  'hem': 164,
#  'kurban': 165,
#  'kraliçe': 166,
#  'insan': 167,
#  'kalp': 168,
#  'kazın': 169,
#  'dram': 170,
#  'biyografik': 171,
#  'kirpi': 172,
#  'sonic': 173,
#  'halka': 174,
#  'yapım': 175,
#  'at': 176,
#  'macera': 177,
#  'konu': 178,
#  'green': 179,
#  'hills': 180,
#  'yerleş': 181,
#  'tek': 182,
#  'istek': 183,
#  'gerçek': 184,
#  'kahraman': 185,
#  'gerek': 186,
#  'özellik': 187,
#  'sahip': 188,
#  'kanıtlayabil': 189,
#  'sınav': 190,
#  'dr': 191,
#  'robotnik': 192,
#  'ortak': 193,
#  'knuckes': 194,
#  'medeniyet': 195,
#  'zümrüt': 196,
#  'ara': 197,
#  'geri': 198,
#  'baş': 199,
#  'yanlış': 200,
#  'el': 201,
#  'geç': 202,
#  'engelle': 203,
#  'yardımcı': 204,
#  'tails': 205,
#  'çıkar': 206,
#  'animasyon': 207,
#  'karanlık': 208,
#  'büyücü': 209,
#  'gellert': 210,
#  'grindelwald': 211,
#  'büyücülük': 212,
#  'kontrol': 213,
#  'geçir': 214,
#  'hareket': 215,
#  'öğren': 216,
#  'profesör': 217,
#  'albus': 218,
#  'dumbledore': 219,
#  'önce': 220,
#  'dur': 221,
#  'başar': 222,
#  'cadı': 223,
#  'cesur': 224,
#  'muggle': 225,
#  'fırıncı': 226,
#  'oluş': 227,
#  'ekip': 228,
#  'yönetim': 229,
#  'büyüzoolog': 230,
#  'newt': 231,
#  'scamander': 232,
#  'a': 233,
#  'emanet': 234,
#  'tehlike': 235,
#  'görev': 236,
#  'üstlen': 237,
#  'canavar': 238,
#  'mücadele': 239,
#  'sayı': 240,
#  'art': 241,
#  'un': 242,
#  'mürit': 243,
#  'savaş': 244,
#  'risk': 245,
#  'karşı': 246,
#  'ne': 247,
#  'kadar': 248,
#  'kenar': 249,
#  'bekleyebil': 250,
#  'fantastik': 251,
#  'aykut': 252,
#  'enişte': 253,
#  'sev': 254,
#  'arife': 255,
#  'türlü': 256,
#  'hikaye': 257,
#  'gülşah': 258,
#  'hazırlık': 259,
#  'ı': 260,
#  'kaçır': 261,
#  'karar': 262,
#  'atabeyoğul': 263,
#  'nin': 264,
#  'damat': 265,
#  'oldukça': 266,
#  'heyecan': 267,
#  'bekle': 268,
#  'durum': 269,
#  'plan': 270,
#  'alt': 271,
#  'üst': 272,
#  'neden': 273,
#  'eski': 274,
#  'talat': 275,
#  'ın': 276,
#  'düğün': 277,
#  'birkaç': 278,
#  'orta': 279,
#  'çık': 280,
#  'iş': 281,
#  'karış': 282,
#  'iyi': 283,
#  'niyet': 284,
#  'saflık': 285,
#  'bela': 286,
#  'mi': 287,
#  'komedi': 288,
#  'morbius': 289,
#  'hastalık': 290,
#  'deva': 291,
#  'bambaşka': 292,
#  'varlık': 293,
#  'bilim': 294,
#  'michael': 295,
#  'muzdarip': 296,
#  'nadir': 297,
#  'gör': 298,
#  'kan': 299,
#  'deneysel': 300,
#  'yöntem': 301,
#  'tedavi': 302,
#  'elektroşok': 303,
#  'terapi': 304,
#  'vampir': 305,
#  'yarasalar': 306,
#  'kullan': 307,
#  'korkunç': 308,
#  'sonuç': 309,
#  'artık': 310,
#  'hiçbir': 311,
#  'şey': 312,
#  'gibi': 313,
#  'birçok': 314,
#  'zorlu': 315,
#  'sürekli': 316,
#  'ihtiyaç': 317,
#  'var': 318,
#  'ışık': 319,
#  'imkansız': 320,
#  'sorun': 321,
#  'sıra': 322,
#  'insanüstü': 323,
#  'aksiyon': 324,
#  'kırmızı': 325,
#  'ergenlik': 326,
#  'getir': 327,
#  'sıkış': 328,
#  'on': 329,
#  'üç': 330,
#  'mei': 331,
#  'lee': 332,
#  'odakla': 333,
#  'beklenti': 334,
#  'beraber': 335,
#  'karmaşa': 336,
#  'kız': 337,
#  'baskı': 338,
#  'koruyucu': 339,
#  'ming': 340,
#  'uzaklaş': 341,
#  'iste': 342,
#  'talihsiz': 343,
#  'vücut': 344,
#  'değişik': 345,
#  'uğraş': 346,
#  'dev': 347,
#  'panda': 348,
#  'li': 349,
#  'hala': 350,
#  'lise': 351,
#  'öğrenci': 352,
#  'müzeyyen': 353,
#  'çoğu': 354,
#  'bekir': 355,
#  'ebru': 356,
#  'hazerhan': 357,
#  'ferdane': 358,
#  'kadir': 359,
#  'arkadaş': 360,
#  'grup': 361,
#  'bütün': 362,
#  'günah': 363,
#  'paylaş': 364,
#  'hiç': 365,
#  'iletişim': 366,
#  'dokuz': 367,
#  'beri': 368,
#  'haberdar': 369,
#  'kardeş': 370,
#  'ali': 371,
#  'gel': 372,
#  'yirmi': 373,
#  'yasak': 374,
#  'hamile': 375,
#  'terket': 376,
#  'yeni': 377,
#  'yarıyıl': 378,
#  'tatil': 379,
#  'fırsat': 380,
#  'tanış': 381,
#  'antalya': 382,
#  'arka': 383,
#  'sokak': 384,
#  'yi': 385,
#  'kabul': 386,
#  'dahil': 387,
#  'iki': 388,
#  'amaç': 389,
#  'birinci': 390,
#  'bolu': 391,
#  'götür': 392,
#  'yaşam': 393,
#  'standart': 394,
#  'eriş': 395,
#  'sağla': 396,
#  'diğer': 397,
#  'kanıtla': 398,
#  'kesiş': 399,
#  'ki': 400,
#  'er': 401,
#  'trabzon': 402,
#  'maçka': 403,
#  'terörist': 404,
#  'mehmetçik': 405,
#  'çatış': 406,
#  'bülbül': 407,
#  'koruma': 408,
#  'şehit': 409,
#  'astsubay': 410,
#  'kıdem': 411,
#  'başçavuş': 412,
#  'ferhat': 413,
#  'gedik': 414,
#  'örümcek': 415,
#  'adam': 416,
#  'ev': 417,
#  'kimlik': 418,
#  'açık': 419,
#  'sır': 420,
#  'ver': 421,
#  'doktor': 422,
#  'strange': 423,
#  'yardım': 424,
#  'ifşa': 425,
#  'halk': 426,
#  'ön': 427,
#  'ser': 428,
#  'kaos': 429,
#  'peter': 430,
#  'aynı': 431,
#  'suç': 432,
#  'lanse': 433,
#  'mj': 434,
#  'ned': 435,
#  'olumsuz': 436,
#  'etkile': 437,
#  'şahit': 438,
#  'üniversite': 439,
#  'şans': 440,
#  'seyirci': 441,
#  'ister': 442,
#  'yakarış': 443,
#  'büyü': 444,
#  'nü': 445,
#  'may': 446,
#  'happy': 447,
#  'kim': 448,
#  'hatırla': 449,
#  'kişi': 450,
#  'parametre': 451,
#  'the': 452,
#  'batman': 453,
#  'sal': 454,
#  'riddler': 455,
#  'isim': 456,
#  'seri': 457,
#  'katil': 458,
#  'dolaş': 459,
#  'bruce': 460,
#  'wayne': 461,
#  'gotham': 462,
#  'city': 463,
#  'sürükle': 464,
#  'gizem': 465,
#  'şehir': 466,
#  'seçkin': 467,
#  'hedef': 468,
#  'sadist': 469,
#  'hain': 470,
#  'gerçekleştirdik': 471,
#  'iz': 472,
#  'sür': 473,
#  'ipuç': 474,
#  'peş': 475,
#  'yol': 476,
#  'süreç': 477,
#  'catwoman': 478,
#  'selina': 479,
#  'kyle': 480,
#  'penguen': 481,
#  'oswald': 482,
#  'cobblepot': 483,
#  'carmine': 484,
#  'falcone': 485,
#  'karakter': 486,
#  'kur': 487,
#  'maske': 488,
#  'düşür': 489,
#  'ni': 490,
#  'huzur': 491,
#  'kavuş': 492,
#  'giriş': 493,
#  'polisiye': 494,
#  'taş': 495,
#  'sherlock': 496,
#  'kurgusal': 497,
#  'dedektif': 498,
#  'rol': 499,
#  'ünle': 500,
#  'wikileaks': 501,
#  'beşinci': 502,
#  'kuvvet': 503,
#  'doğru': 504,
#  'star': 505,
#  'trek': 506,
#  'ımitation': 507,
#  'game': 508,
#  'enigma': 509,
#  'benedict': 510,
#  'cumberbatch': 511,
#  'ünlü': 512,
#  'kez': 513,
#  'yönetmen': 514,
#  'scott': 515,
#  'derrickson': 516,
#  'kamera': 517,
#  'sadık': 518,
#  'usta': 519,
#  'wong': 520,
#  'dilberay': 521,
#  'veda': 522,
#  'dilber': 523,
#  'ay': 524,
#  'kahramanmaraş': 525,
#  'ta': 526,
#  'sekiz': 527,
#  'çadır': 528,
#  'başla': 529,
#  'para': 530,
#  'karşılık': 531,
#  'sat': 532,
#  'tutku': 533,
#  'söyle': 534,
#  'yüz': 535,
#  'dayak': 536,
#  'ye': 537,
#  'işkence': 538,
#  'çek': 539,
#  'her': 540,
#  'acı': 541,
#  'adım': 542,
#  'boyunca': 543,
#  'zirve': 544,
#  'dip': 545,
#  'vur': 546,
#  'düş': 547,
#  'kuyu': 548,
#  'doru': 549,
#  'orman': 550,
#  'kurtar': 551,
#  'karşılaş': 552,
#  'karatay': 553,
#  'alaca': 554,
#  'hayvan': 555,
#  'sirk': 556,
#  'üzer': 557,
#  'yakın': 558,
#  'yı': 559,
#  'geçer': 560,
#  'zekice': 561,
#  'saye': 562,
#  'sürpriz': 563,
#  'kaç': 564,
#  'bebek': 565,
#  'şempanze': 566,
#  'şöbi': 567,
#  'onlarla': 568,
#  'geçen': 569,
#  'gerçekten': 570,
#  'will': 571,
#  'salas': 572,
#  'justin': 573,
#  'timberlake': 574,
#  'hata': 575,
#  'cinayet': 576,
#  'hüküm': 577,
#  'giy': 578,
#  'hapishane': 579,
#  'sistem': 580,
#  'çöker': 581,
#  'zira': 582,
#  'rahat': 583,
#  'satın': 584,
#  'alın': 585,
#  'zengin': 586,
#  'son': 587,
#  'fakir': 588,
#  'ele': 589,
#  'üstelik': 590,
#  'ekle': 591,
#  'güçs': 592,
#  'üz': 593,
#  'sadece': 594,
#  'dile': 595,
#  'ödünç': 596,
#  'hatta': 597,
#  'bazen': 598,
#  'çalar': 599,
#  'yoz': 600,
#  'kaldır': 601,
#  'başrol': 602,
#  'dönem': 603,
#  'sinema': 604,
#  'yönel': 605,
#  'scarlett': 606,
#  'johansson': 607,
#  'an': 608,
#  'amanda': 609,
#  'seyfried': 610,
#  'oyun': 611,
#  'kadro': 612,
#  'olivia': 613,
#  'wilde': 614,
#  'alex': 615,
#  'pettyfer': 616,
#  'cillian': 617,
#  'murphy': 618,
#  'gattaca': 619,
#  's': 620,
#  'm': 621,
#  'lord': 622,
#  'of': 623,
#  'war': 624,
#  'yaz': 625,
#  'yönet': 626,
#  'truman': 627,
#  'show': 628,
#  'terminal': 629,
#  'senaryo': 630,
#  'kalem': 631,
#  'andrew': 632,
#  'niccol': 633,
#  'proje': 634,
#  'yarat': 635,
#  'bilimkurgu': 636,
#  'edebiyat': 637,
#  'anastasia': 638,
#  'steele': 639,
#  'çekici': 640,
#  'christian': 641,
#  'grey': 642,
#  'röportaj': 643,
#  'görüşme': 644,
#  'tavır': 645,
#  'biraz': 646,
#  'mesafe': 647,
#  'yakışıklı': 648,
#  'cazibe': 649,
#  'koy': 650,
#  'çekim': 651,
#  'bırak': 652,
#  'fakat': 653,
#  'doyum': 654,
#  'nokta': 655,
#  'ulaş': 656,
#  'seks': 657,
#  'söz': 658,
#  'gizli': 659,
#  'şehvet': 660,
#  'sap': 661,
#  'mı': 662,
#  'l': 663,
#  'james': 664,
#  'çok': 665,
#  'liste': 666,
#  'ad': 667,
#  'roman': 668,
#  'uyarla': 669,
#  'sam': 670,
#  'taylor': 671,
#  'johnson': 672,
#  'jamie': 673,
#  'dornan': 674,
#  'dakota': 675,
#  'romantik': 676,
#  'recep': 677,
#  'ivedik': 678,
#  'konya': 679,
#  'kenya': 680,
#  'davet': 681,
#  'hal': 682,
#  'kuru': 683,
#  'fasulye': 684,
#  'festival': 685,
#  'çağır': 686,
#  'memnuniyet': 687,
#  'karşıla': 688,
#  'nurullah': 689,
#  'talihsizlik': 690,
#  'ikili': 691,
#  'seyahat': 692,
#  'acente': 693,
#  'coğrafya': 694,
#  'bulun': 695,
#  'birden': 696,
#  'düşman': 697,
#  'yerli': 698,
#  'kabile': 699,
#  'has': 700,
#  'vahşi': 701,
#  'ayak': 702,
#  'birbiri': 703,
#  'ilginç': 704,
#  'milyoner': 705,
#  'sandık': 706,
#  'kolay': 707,
#  'yeniden': 708,
#  'çift': 709,
#  'barışmalar': 710,
#  'bit': 711,
#  'geçmiş': 712,
#  'şeytan': 713,
#  'öfke': 714,
#  'kıskançlıklar': 715,
#  'tyler': 716,
#  'hoechlin': 717,
#  'basinger': 718,
#  'marcia': 719,
#  'gay': 720,
#  'harden': 721,
#  'bella': 722,
#  'heathcote': 723,
#  'erotik': 724,
#  'dayı': 725,
#  'kabadayı': 726,
#  'adalet': 727,
#  'duygu': 728,
#  'cesaret': 729,
#  'merhametli': 730,
#  'haylaz': 731,
#  'bık': 732,
#  'taraf': 733,
#  'köy': 734,
#  'istanbul': 735,
#  'gönder': 736,
#  'kahvecilik': 737,
#  'köylü': 738,
#  'seyfi': 739,
#  'ailemine': 740,
#  'yüksel': 741,
#  'kayıp': 742,
#  'yazar': 743,
#  'loretta': 744,
#  'sage': 745,
#  'inziva': 746,
#  'zeki': 747,
#  'dash': 748,
#  'canlan': 749,
#  'ada': 750,
#  'kapak': 751,
#  'model': 752,
#  'popüler': 753,
#  'egzotik': 754,
#  'hak': 755,
#  'kitap': 756,
#  'tanıtım': 757,
#  'turne': 758,
#  'eksantrik': 759,
#  'milyarder': 760,
#  'antik': 761,
#  'hazine': 762,
#  'vakit': 763,
#  'uygun': 764,
#  'yetkili': 765,
#  'şeytani': 766,
#  'yüzük': 767,
#  'hükümet': 768,
#  'yakala': 769,
#  'devlet': 770,
#  'eggman': 771,
#  'kasaba': 772,
#  'şerif': 773,
#  'tom': 774,
#  'wachowski': 775,
#  'kuzey': 776,
#  'intikam': 777,
#  'viking': 778,
#  'prens': 779,
#  'kral': 780,
#  'aurvandil': 781,
#  'imparatorluk': 782,
#  'oğul': 783,
#  'amleth': 784,
#  'devret': 785,
#  'üvey': 786,
#  'fjölnir': 787,
#  'taht': 788,
#  'amca': 789,
#  'gudrun': 790,
#  'u': 791,
#  'yemin': 792,
#  'slav': 793,
#  'akın': 794,
#  'kahin': 795,
#  'tut': 796,
#  'tarihi': 797,
#  'uzak': 798,
#  'dune': 799,
#  'çöl': 800,
#  'gezegen': 801,
#  'arrakis': 802,
#  'paul': 803,
#  'atreides': 804,
#  'galaksi': 805,
#  'fark': 806,
#  'rakip': 807,
#  'feodal': 808,
#  'değer': 809,
#  'kaynak': 810,
#  'üretici': 811,
#  'asil': 812,
#  'derece': 813,
#  'talep': 814,
#  'baharat': 815,
#  'yüksek': 816,
#  'bilinç': 817,
#  'uzun': 818,
#  'sun': 819,
#  'ciddi': 820,
#  'etki': 821,
#  'ayrıca': 822,
#  'yıldızlarara': 823,
#  'gezin': 824,
#  'tır': 825,
#  'harkonen': 826,
#  'tuzak': 827,
#  'darmadağın': 828,
#  'firari': 829,
#  'kazan': 830,
#  'isyan': 831,
#  'evren': 832,
#  'seyir': 833,
#  'ihtimal': 834,
#  'frank': 835,
#  'herbert': 836,
#  'televizyon': 837,
#  'beyaz': 838,
#  'perde': 839,
#  'legendary': 840,
#  'entertainment': 841,
#  'uyaramanın': 842,
#  'koltuk': 843,
#  'arrival': 844,
#  'sicario': 845,
#  'blade': 846,
#  'runner': 847,
#  'damga': 848,
#  'oscar': 849,
#  'aday': 850,
#  'denis': 851,
#  'villeneuve': 852,
#  'otur': 853,
#  'eric': 854,
#  'roth': 855,
#  'yapımcılık': 856,
#  'thomas': 857,
#  'tull': 858,
#  'mary': 859,
#  'parent': 860,
#  'cale': 861,
#  'boyter': 862,
#  'hız': 863,
#  'do': 864,
#  'dominic': 865,
#  'toretto': 866,
#  'nun': 867,
#  'öncelik': 868,
#  'brian': 869,
#  'koru': 870,
#  'letty': 871,
#  'sakin': 872,
#  'siber': 873,
#  'cipher': 874,
#  'terk': 875,
#  'jakob': 876,
#  'lider': 877,
#  'yık': 878,
#  'venom': 879,
#  'organizma': 880,
#  'taşı': 881,
#  'eddie': 882,
#  'brock': 883,
#  'infaz': 884,
#  'cletus': 885,
#  'kasady': 886,
#  'shriek': 887,
#  'alış': 888,
#  'kötü': 889,
#  'döv': 890,
#  'muazzam': 891,
#  'açlık': 892,
#  'tatmin': 893,
#  'gazeteci': 894,
#  'alevlen': 895,
#  'herkes': 896,
#  'şekil': 897,
#  'yetiş': 898,
#  'dört': 899,
#  'duvar': 900,
#  'eğitim': 901,
#  'sakla': 902,
#  'çılgın': 903,
#  'parti': 904,
#  'kaşı': 905,
#  'ayıramaya': 906,
#  'delişmen': 907,
#  'karizmatik': 908,
#  'jack': 909,
#  'tüccar': 910,
#  'joy': 911,
#  'mcnally': 912,
#  'las': 913,
#  'vegas': 914,
#  'tantanalı': 915,
#  'haftason': 916,
#  'ful': 917,
#  'tesadüfi': 918,
#  'şenlik': 919,
#  'hayal': 920,
#  'meyal': 921,
#  'hatıra': 922,
#  'new': 923,
#  'york': 924,
#  'lu': 925,
#  'hisset': 926,
#  'stil': 927,
#  'sözleşme': 928,
#  'imza': 929,
#  'belki': 930,
#  'herşey': 931,
#  'bura': 932,
#  'kumarhane': 933,
#  'aşırı': 934,
#  'merkezi': 935,
#  'cinsiyet': 936,
#  'iddia': 937,
#  'gladyatör': 938,
#  'sahiplik': 939,
#  'saadet': 940,
#  'altı': 941,
#  'ganimet': 942,
#  'hararet': 943,
#  'kıvılcım': 944,
#  'birgün': 945,
#  'sıçra': 946,
#  'sahte': 947,
#  'şaşırtıcı': 948,
#  'soru': 949,
#  'cevap': 950,
#  'izle': 951,
#  'başarısızlık': 952,
#  'adler': 953,
#  'chris': 954,
#  'evans': 955,
#  'florida': 956,
#  'kırsal': 957,
#  'yeğen': 958,
#  'okul': 959,
#  'hemen': 960,
#  'yaftala': 961,
#  'evelyn': 962,
#  'yasal': 963,
#  'marc': 964,
#  'webb': 965,
#  'drama': 966,
#  'ağırlık': 967,
#  'suzanne': 968,
#  'kristin': 969,
#  'meslek': 970,
#  'eş': 971,
#  'samuel': 972,
#  'yvan': 973,
#  'attal': 974,
#  'fransa': 975,
#  'güney': 976,
#  'sınıf': 977,
#  'mensup': 978,
#  'kırk': 979,
#  'koca': 980,
#  'görün': 981,
#  'bahçe': 982,
#  'inşaat': 983,
#  'göçmen': 984,
#  'ıvan': 985,
#  'sergi': 986,
#  'pez': 987,
#  'sefer': 988,
#  'çevre': 989,
#  'konum': 990,
#  'umursa': 991,
#  'ateş': 992,
#  'suzzanne': 993,
#  'itiraf': 994,
#  'cinsel': 995,
#  'tanı': 996,
#  'fransız': 997,
#  'senarist': 998,
#  'cather': 999,
#  ...}

# %% [markdown]
# TF matrisi oluşturma

# %%
film_sayisi = len(filmler)
sozluk_buyuklugu = len(word2idx)

print(film_sayisi, sozluk_buyuklugu)
# Out:
# 5261 24437

# %%
tf = np.zeros((film_sayisi, sozluk_buyuklugu))

for i, film in enumerate(filmler):
    sozcukler = film.split()
    for sozcuk in sozcukler:
        tf[i, word2idx[sozcuk]] += 1 # sözcük sayma

    tf[i] = tf[i] / len(sozcukler) # normalizasyon

print(tf[0])
# Out:
# [0.00813008 0.00406504 0.00406504 ... 0.         0.         0.        ]

# %% [markdown]
# IDF vektörü oluşturma

# %%
# Örnek
toy_tf = np.array([
    [0.5, 0.0, 0.0, 0.5],
    [0.0, 0.0, 0.5, 0.5],
    [0.0, 0.1, 0.0, 0.9],
    [0.3, 0.0, 0.1, 0.6],
    [0.7, 0.0, 0.0, 0.3],
])

toy_doc_freq = np.sum(toy_tf > 0, axis=0)
toy_doc_freq

# %%
toy_idf = 5 / toy_doc_freq
print(toy_idf)
toy_idf = np.log(toy_idf)
print(toy_idf)

# %%
# gerçek hesaplama kısmı
doc_freq = np.sum(tf > 0, axis=0)
print(doc_freq)

idf = np.log(film_sayisi / doc_freq)
print(idf)

# %% [markdown]
# TF-IDF matrisi oluşturma

# %%
tf_idf = tf * idf

# %% [markdown]
# Benzerlik hesaplama ve sorgular

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def film2str(row_index):
    film = df.iloc[row_index]
    adi = film["film adi"]
    turu = ", ".join(film["tur_list"])
    ozet = re.sub(r"\n+", "\n", film["ozet ve detaylar"]).strip()
    if len(ozet) > 200:
        ozet = ozet[:200] + "..."

    return f"Film adı: {adi} \nTürü: {turu} \nÖzeti: {ozet}"


print(film2str(3))

# %%
def benzerlerini_bul(film_adi, benzer_film_sayisi):
    film_indexi = df[df["film adi"] == film_adi].index[0]
    print("Aranan Film:")
    print(film2str(film_indexi))
    print()
    print("* " * 30)
    print()

    benzerlikler = []
    sorgu_film = tf_idf[film_indexi]
    for vec in tf_idf:
        benzerlik = cos_sim(sorgu_film, vec)
        benzerlikler.append(benzerlik)

    en_benzer_film_indexleri = (- np.array(benzerlikler)
                                ).argsort()[:benzer_film_sayisi + 1]
    print("Benzer Filmler:\n")
    for i, film_idx in enumerate(en_benzer_film_indexleri[1:]):
        print(str(i+1) + ") " + film2str(film_idx))
        print()
        print("- " * 20)
        print()

# %%
benzerlerini_bul("Kirpi Sonic 2", 3)
